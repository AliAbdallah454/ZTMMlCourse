# %%
import pandas as pd
# Out:
# C:\Users\Ali\AppData\Local\Temp\ipykernel_24520\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
series = pd.Series(["BMW", "Toyota", "Honda"])
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colors = pd.Series(["red", "blue", "white"])
colors
# Out:
# 0      red
# 1     blue
# 2    white
# dtype: object

# %%
car_data = pd.DataFrame({"Car Make": series, "Colors": colors})

# %%
car_data
# Out:
#   Car Make Colors
# 0      BMW    red
# 1   Toyota   blue
# 2    Honda  white

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exp_car_sales.csv", index=False)

# %% [markdown]
# # Describing Data

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_data
# Out:
#   Car Make Colors
# 0      BMW    red
# 1   Toyota   blue
# 2    Honda  white

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_prices = pd.Series([3_000, 5_000, 10_000])
car_prices.mean()
# Out:
# 6000.0

# %%
car_sales["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# # Viewing and Selecting data

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %% [markdown]
# loc and iloc

# %%
animals = pd.Series(["Cat", "Dog", "Panda"], index=[1, 1, 5])
animals
animals.iloc[1]
# Out:
# 'Dog'

# %%
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales[car_sales.Make == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %% [markdown]
# Group-by

# %%
car_sales.groupby(["Doors"]).mean()
# print(car_sales.dtypes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\groupby\ops.py:863, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     861     preserve_dtype = True
# --> 863 result = self._aggregate_series_pure_python(obj, func)
#     865 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\groupby\ops.py:884, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     883 for i, group in enumerate(splitter):
# --> 884     res = func(group)
#     885     res = extract_result(res)
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\series.py:6529, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6521 @doc(make_doc("mean", ndim=1))
#    6522 def mean(
#    6523     self,
#    (...)
#    6527     **kwargs,
#    6528 ):
# -> 6529     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\generic.py:12413, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12406 def mean(
#   12407     self,
#   12408     axis: Axis | None = 0,
#    (...)
#   12411     **kwargs,
#   12412 ) -> Series | float:
# > 12413     return self._stat_function(
#   12414         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12415     )
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\generic.py:12370, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12368 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12370 return self._reduce(
#   12371     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12372 )
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\series.py:6437, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6433     raise TypeError(
#    6434         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6435         "with non-numeric dtypes."
#    6436     )
# -> 6437 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'Toyota' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 car_sales.groupby(["Doors"]).mean()
#       2 # print(car_sales.dtypes)
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\internals\managers.py:1470, in BlockManager.grouped_reduce(self, func)
#    1466 if blk.is_object:
#    1467     # split on object-dtype blocks bc some columns may raise
#    1468     #  while others do not.
#    1469     for sb in blk._split():
# -> 1470         applied = sb.apply(func)
#    1471         result_blocks = extend_blocks(applied, result_blocks)
#    1472 else:
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File c:\Users\Ali\Desktop\virEnv\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales["Price"] = car_sales["Price"].str.replace(',', '').astype(int)

# %%
car_sales.Price.plot()

# %%
car_sales.dropna(inplace=True)

# %%
missingCar = pd.read_csv("car-sales-missing-data.csv")

# %%
missingCar.dropna(inplace=True)

# %%
missingCar.to_csv("car-sales-missing-droped.csv")

# %%
seats_column = pd.Series([5] * 5)
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)
# Out:
# C:\Users\Ali\AppData\Local\Temp\ipykernel_15832\1647811259.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales["Seats"].fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %%
car_sales[car_sales["Colour"].str.lower() == "white"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats
# 0  Toyota  White         150043      4  $4,000.00    5.0
# 4  Nissan  White         213095      4  $3,500.00    5.0
# 8  Toyota  White          60000      4  $6,250.00    5.0
# 9  Nissan  White          31600      4  $9,700.00    5.0

# %%
# Column from list
fuel_economy = [6] * len(car_sales)
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM
# 0  Toyota  White         150043      4   $4,000.00    5.0               6
# 1   Honda    Red          87899      4   $5,000.00    5.0               6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0               6
# 3     BMW  Black          11179      5  $22,000.00    5.0               6
# 4  Nissan  White         213095      4   $3,500.00    5.0               6
# 5  Toyota  Green          99213      4   $4,500.00    5.0               6
# 6   Honda   Blue          45698      4   $7,500.00    5.0               6
# 7   Honda   Blue          54738      4   $7,000.00    5.0               6
# 8  Toyota  White          60000      4   $6,250.00    5.0               6
# 9  Nissan  White          31600      4   $9,700.00    5.0               6

# %%
car_sales["Total Fuel Used in L"] = car_sales["Odometer (KM)"] / 100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0               6
# 1   Honda    Red          87899      4   $5,000.00    5.0               6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0               6
# 3     BMW  Black          11179      5  $22,000.00    5.0               6
# 4  Nissan  White         213095      4   $3,500.00    5.0               6
# 5  Toyota  Green          99213      4   $4,500.00    5.0               6
# 6   Honda   Blue          45698      4   $7,500.00    5.0               6
# 7   Honda   Blue          54738      4   $7,000.00    5.0               6
# 8  Toyota  White          60000      4   $6,250.00    5.0               6
# 9  Nissan  White          31600      4   $9,700.00    5.0               6
#
#    Total Fuel Used  Total Fuel Used in L
# 0          9002.58               9002.58
# 1          5273.94               5273.94
# 2          1952.94               1952.94
# 3           670.74                670.74
# 4         12785.70              12785.70
# 5          5952.78               5952.78
# 6          2741.88               2741.88
# 7          3284.28               3284.28
# 8          3600.00               3600.00
# 9          1896.00               1896.00

# %%
car_sales["Number of Wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0               6
# 1   Honda    Red          87899      4   $5,000.00    5.0               6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0               6
# 3     BMW  Black          11179      5  $22,000.00    5.0               6
# 4  Nissan  White         213095      4   $3,500.00    5.0               6
# 5  Toyota  Green          99213      4   $4,500.00    5.0               6
# 6   Honda   Blue          45698      4   $7,500.00    5.0               6
# 7   Honda   Blue          54738      4   $7,000.00    5.0               6
# 8  Toyota  White          60000      4   $6,250.00    5.0               6
# 9  Nissan  White          31600      4   $9,700.00    5.0               6
#
#    Total Fuel Used  Total Fuel Used in L  Number of Wheels
# 0          9002.58               9002.58                 4
# 1          5273.94               5273.94                 4
# 2          1952.94               1952.94                 4
# 3           670.74                670.74                 4
# 4         12785.70              12785.70                 4
# 5          5952.78               5952.78                 4
# 6          2741.88               2741.88                 4
# 7          3284.28               3284.28                 4
# 8          3600.00               3600.00                 4
# 9          1896.00               1896.00                 4

# %%
car_sales["Passed road Safety"] = True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0               6
# 1   Honda    Red          87899      4   $5,000.00    5.0               6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0               6
# 3     BMW  Black          11179      5  $22,000.00    5.0               6
# 4  Nissan  White         213095      4   $3,500.00    5.0               6
# 5  Toyota  Green          99213      4   $4,500.00    5.0               6
# 6   Honda   Blue          45698      4   $7,500.00    5.0               6
# 7   Honda   Blue          54738      4   $7,000.00    5.0               6
# 8  Toyota  White          60000      4   $6,250.00    5.0               6
# 9  Nissan  White          31600      4   $9,700.00    5.0               6
#
#    Total Fuel Used  Total Fuel Used in L  Number of Wheels  Passed road Safety
# 0          9002.58               9002.58                 4                True
# 1          5273.94               5273.94                 4                True
# 2          1952.94               1952.94                 4                True
# 3           670.74                670.74                 4                True
# 4         12785.70              12785.70                 4                True
# 5          5952.78               5952.78                 4                True
# 6          2741.88               2741.88                 4                True
# 7          3284.28               3284.28                 4                True
# 8          3600.00               3600.00                 4                True
# 9          1896.00               1896.00                 4                True

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0               6
# 1   Honda    Red          87899      4   $5,000.00    5.0               6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0               6
# 3     BMW  Black          11179      5  $22,000.00    5.0               6
# 4  Nissan  White         213095      4   $3,500.00    5.0               6
#
#    Total Fuel Used  Total Fuel Used in L  Number of Wheels  Passed road Safety
# 0          9002.58               9002.58                 4                True
# 1          5273.94               5273.94                 4                True
# 2          1952.94               1952.94                 4                True
# 3           670.74                670.74                 4                True
# 4         12785.70              12785.70                 4                True

# %%
car_sales.drop("Total Fuel Used", axis=1, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0               6
# 1   Honda    Red          87899      4   $5,000.00    5.0               6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0               6
# 3     BMW  Black          11179      5  $22,000.00    5.0               6
# 4  Nissan  White         213095      4   $3,500.00    5.0               6
# 5  Toyota  Green          99213      4   $4,500.00    5.0               6
# 6   Honda   Blue          45698      4   $7,500.00    5.0               6
# 7   Honda   Blue          54738      4   $7,000.00    5.0               6
# 8  Toyota  White          60000      4   $6,250.00    5.0               6
# 9  Nissan  White          31600      4   $9,700.00    5.0               6
#
#    Total Fuel Used in L  Number of Wheels  Passed road Safety
# 0               9002.58                 4                True
# 1               5273.94                 4                True
# 2               1952.94                 4                True
# 3                670.74                 4                True
# 4              12785.70                 4                True
# 5               5952.78                 4                True
# 6               2741.88                 4                True
# 7               3284.28                 4                True
# 8               3600.00                 4                True
# 9               1896.00                 4                True

# %%
car_sales.to_csv("TestBitch.csv")

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled.sample(frac=0.1)
# Out:
#     Make Colour  Odometer (KM)  Doors      Price
# 7  Honda   Blue          54738      4  $7,000.00

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda   Blue          54738      4   $7,000.00
# 2  Toyota  Green          99213      4   $4,500.00
# 3     BMW  Black          11179      5  $22,000.00
# 4   Honda   Blue          45698      4   $7,500.00
# 5  Nissan  White         213095      4   $3,500.00
# 6  Toyota  White          60000      4   $6,250.00
# 7   Honda    Red          87899      4   $5,000.00
# 8  Toyota   Blue          32549      3   $7,000.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_shuffled = car_sales_shuffled.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 8  Toyota   Blue          32549      3   $7,000.00
# 7   Honda    Red          87899      4   $5,000.00
# 2  Toyota  Green          99213      4   $4,500.00
# 5  Nissan  White         213095      4   $3,500.00
# 6  Toyota  White          60000      4   $6,250.00
# 3     BMW  Black          11179      5  $22,000.00
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda   Blue          54738      4   $7,000.00
# 4   Honda   Blue          45698      4   $7,500.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x : x / 1.6)

# %%
car_sales.rename(columns={"Odometer (KM)": "Odometer (M)"}, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (M)  Doors       Price
# 0  Toyota  White     93776.875      4   $4,000.00
# 1   Honda    Red     54936.875      4   $5,000.00
# 2  Toyota   Blue     20343.125      3   $7,000.00
# 3     BMW  Black      6986.875      5  $22,000.00
# 4  Nissan  White    133184.375      4   $3,500.00
# 5  Toyota  Green     62008.125      4   $4,500.00
# 6   Honda   Blue     28561.250      4   $7,500.00
# 7   Honda   Blue     34211.250      4   $7,000.00
# 8  Toyota  White     37500.000      4   $6,250.00
# 9  Nissan  White     19750.000      4   $9,700.00
